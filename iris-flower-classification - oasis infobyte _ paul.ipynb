# %% [markdown]
# ## OASIS INFOBYTE  -  INTERNSHIP
# ## TASK 1 - IRIS FLOWER CLASSIFICATION

# %% [markdown]
# Iris flower has three species; setosa, versicolor, and virginica, which differs according to their measurements. Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# ## INTRODUCTION :
# ##### The IRIS dataset is a simple and a well-known dataset. Is most often used dataset for easy understanding and learning of machine learning concepts.This dataset consists of information about three different species of Iris flowers:
#     1.Iris setosa
#     2.Iris versicolor
#     3.Iris virginica
#
# #### These  given features helps us in distinguishing between the three Iris species.
#     1.Sepal length in cms
#     2.Sepal width in cms
#     3.Petal length in cms
#     4.Petal width in cms

# %% [markdown]
# ## OBJECTIVE:
#
# Build a predictive machine learning model that can learn from the measurements of the iris species and classify them using data science techniques in Python.
#
#
# Process :-
#
#     1.Reading and Understanding Data
#     2.Extrapolatory Data Analysis
#     3.Data Preparation
#     4.Building Model and testing
#     5.Inference

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Step 1- Reading and Understanding Data

# %%
# import required libraries for dataframe and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
## Loading the required dataset (Iris Dataset)
iris_df = pd.read_csv('D:/DATA/Oasis Infobyte/Task 1 - Iris/Iris.csv')
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# shape
print("Iris Data Size  :" ,iris_df.size)
print("Iris Data Shape :" ,iris_df.shape)
# Out:
# Iris Data Size  : 900
# Iris Data Shape : (150, 6)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# No null values and all data is matching its data type

# %%
# Dropping the Id column as it has no significance here
iris_df=iris_df.drop("Id",axis=1)
iris_df.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# ======================================================================================================================================================

# %% [markdown]
# ## Step -2 - Extrapolatory Data Analysis

# %%
plt.figure(figsize=(12,4))


# Create a scatter plot
plt.subplot(1,2,1)

sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species',data=iris_df)
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')


plt.subplot(1,2,2)
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=iris_df)
plt.title('Scatter Plot of PetalLength vs Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')

sns.set_palette('deep')
plt.show()

# %%
# set the style of the plots
ax = sns.set_style('darkgrid')

plt.figure(figsize=(18,3))

# box plot of sepal length by target
ax = plt.subplot(1,4,1)
ax = sns.boxplot(x='Species', y='SepalLengthCm', data=iris_df, palette ='deep')
plt.title('Sepal Length by Target')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')


# box plot of petal length by target
ax = plt.subplot(1,4,2)
ax = sns.boxplot(x='Species', y='SepalWidthCm', data=iris_df, palette ='deep')
plt.title('Sepal Width by Target')
plt.ylabel('Sepal Width(cm)')


# box plot of petal length by target
ax = plt.subplot(1,4,3)
ax = sns.boxplot(x='Species', y='PetalLengthCm', data=iris_df, palette ='deep')
plt.title('Petal Length by Target')
plt.ylabel('Petal Length (cm)')


# box plot of petal length by target
ax = plt.subplot(1,4,4)
ax = sns.boxplot(x='Species', y='PetalWidthCm', data=iris_df, palette ='deep')
plt.title('Petal Width by Target')
plt.ylabel('Petal Width (cm)')

plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(18,3))

# histogram of sepal length
plt.subplot(1,4,1)
sns.histplot(data=iris_df, x='SepalLengthCm', hue='Species', palette='Set2', kde=True)
plt.title('Sepal Length Distribution')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Count')

# histogram of sepal width
plt.subplot(1,4,2)
sns.histplot(data=iris_df, x='SepalWidthCm', hue='Species', palette='Set3', kde=True)
plt.title('Sepal Width Distribution')
plt.xlabel('Sepal Width (cm)')

# histogram of petal length
plt.subplot(1,4,3)
sns.histplot(data=iris_df, x='PetalLengthCm', hue='Species', palette='Set2', kde=True)
plt.title('Petal Length Distribution')
plt.xlabel('Petal Length (cm)')

# histogram of petal Width
plt.subplot(1,4,4)
sns.histplot(data=iris_df, x='PetalWidthCm', hue='Species', palette='Set3', kde=True)
plt.title('Petal Length Distribution')
plt.xlabel('Petal Length (cm)')

plt.show()

# %%
# creating a pair plot
plt.close() 
sns.set_style("darkgrid")
sns.pairplot(iris_df,hue="Species")
plt.show()

# %% [markdown]
# ======================================================================================================================================================

# %% [markdown]
# ## Step -3 - Data Preparation

# %%
#Display the number of samples for each species
iris_df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#Label Encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

iris_df['Species']=le.fit_transform(iris_df['Species'])

# %%
# the correlation matrix
iris_df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# Species             0.782561     -0.419446       0.949043      0.956464
#
#                 Species
# SepalLengthCm  0.782561
# SepalWidthCm  -0.419446
# PetalLengthCm  0.949043
# PetalWidthCm   0.956464
# Species        1.000000

# %%
corr = iris_df.corr(method='kendall')
plt.figure(figsize=(6, 4))
sns.heatmap(corr, vmax=.3, linewidths=0.05, annot=True, cmap='RdBu', linecolor="black")
plt.title('Correlation between features', weight = 'heavy')
plt.show()

# %% [markdown]
# ======================================================================================================================================================

# %% [markdown]
# ## Step -4 - Model Building

# %%
#Importing libraries for model building
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import precision_recall_curve
from sklearn.svm import SVC

# %%
# features or the dependent variables
X = iris_df.drop(columns = ['Species'],axis=1)

# target 
Y = iris_df['Species']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 2)

# %% [markdown]
# Selecting the features from the above conducted tests and splitting the data into 80 - 20 train - test groups.

# %%
def model(classifier):
    
    classifier.fit(X_train,Y_train)
    prediction = classifier.predict(X_test)
    cv = RepeatedStratifiedKFold(n_splits = 10,n_repeats = 3,random_state = 1)
    print("ACCURACY OF THE MODEL       : ",'{0:.2%}'.format(accuracy_score(Y_test,prediction)))

# %%
def model_evaluation(classifier):
    
    # Confusion Matrix
    cm = confusion_matrix(Y_test,classifier.predict(X_test))
    names = ['True Neg','False Pos','False Neg','True Pos']
    counts = [value for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(names,counts,percentages)]
    labels = np.asarray(labels).reshape(2,2)

    plt.figure(figsize=(3,2))    
    sns.heatmap(cm,annot=True,fmt="d",cbar=False)
    plt.xlabel("Predicted value")
    plt.ylabel("Actual value")
    plt.title("Confusion Matrix")

    # Classification Report
    print("------------------------------------------------------------")
    print(classification_report(Y_test,classifier.predict(X_test)))
    print("------------------------------------------------------------")

# %% [markdown]
# 1) Model - LOGISITIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

classifier_lr = LogisticRegression(random_state = 0, C=10, penalty= 'l2') 

model(classifier_lr)

model_evaluation(classifier_lr)
# Out:
# ACCURACY OF THE MODEL       :  100.00%
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# ------------------------------------------------------------

# %% [markdown]
# 2) Model -  DECISION TREES :

# %%
from sklearn.tree import DecisionTreeClassifier

classifier_dt = DecisionTreeClassifier(random_state = 1000,max_depth = 6,min_samples_leaf = 1)

model(classifier_dt)

model_evaluation(classifier_dt)
# Out:
# ACCURACY OF THE MODEL       :  93.33%
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       0.88      0.88      0.88         8
#            2       0.88      0.88      0.88         8
#
#     accuracy                           0.93        30
#    macro avg       0.92      0.92      0.92        30
# weighted avg       0.93      0.93      0.93        30
#
# ------------------------------------------------------------

# %% [markdown]
# 3) Model -  RANDOM FOREST :

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rf = RandomForestClassifier(max_depth = 4,random_state = 0)

model(classifier_rf)

model_evaluation(classifier_rf)
# Out:
# ACCURACY OF THE MODEL       :  96.67%
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.88      0.93         8
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# ------------------------------------------------------------

# %% [markdown]
# 4) Model-  SUPPORT VECTOR MACHINES:

# %%
from sklearn.svm import SVC

classifier_svc = SVC(kernel = 'linear',C = 0.1)

model(classifier_svc)

model_evaluation(classifier_svc)
# Out:
# ACCURACY OF THE MODEL       :  96.67%
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.88      0.93         8
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# ------------------------------------------------------------

# %% [markdown]
# 5)Model -  K- NEAREST NEIGHBOUR :

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier_knn = KNeighborsClassifier(leaf_size = 1, n_neighbors = 3,p = 1)

model(classifier_knn)

model_evaluation(classifier_knn)
# Out:
# ACCURACY OF THE MODEL       :  100.00%
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# ------------------------------------------------------------

# %%
### Perfomance result of the models used.

# Creating a dictionary with the data
data = { 'ML Algorithm': ['Logistic Regression', 'Decision Tree Classifier', 'Random Forest Classifier', 'Support Vector Classifier', 'K-Nearest Neighbors Classifier'],
          'Accuracy': [100.00, 93.33, 96.67, 96.67, 100.00]}

# Create a DataFrame
performance_df = pd.DataFrame(data)

performance_df
# Out:
#                      ML Algorithm  Accuracy
# 0             Logistic Regression    100.00
# 1        Decision Tree Classifier     93.33
# 2        Random Forest Classifier     96.67
# 3       Support Vector Classifier     96.67
# 4  K-Nearest Neighbors Classifier    100.00

# %%
plt.figure(figsize=(12, 4))

ax = sns.barplot(x= 'ML Algorithm', y='Accuracy', data=performance_df, palette='deep')

bar_width = 0.5
for bar in ax.patches:
    bar.set_width(bar_width)

for container in ax.containers:
    ax.bar_label(container)

plt.title('Performance Metrics Comparison', color='Red', font='Lucida Calligraphy', fontsize=21)
plt.xlabel('ML Algorithm',color='Red',font='Lucida Calligraphy', fontsize=21)
plt.ylim(70, 100)
plt.ylabel('Percentage  Accuracy(%)', fontsize=18)

plt.xticks(rotation=5, fontsize=12)
plt.show()

# %% [markdown]
# ======================================================================================================================================================

# %% [markdown]
# ## Step -5 - Inference
#
# From the above performance score  - LogisticRegression and KNN model shows highest accuracy.
# Using LogisticRegression a predicitive output is given below.

# %% [markdown]
# ## Building a predictive system:

# %%
#entering external inputs
inputdata=(6.0, 2.9, 4.5, 1.5)

#change input data into numpy array
inputdata_as_numpy_array=np.asarray(inputdata)

#reshape the numpy array as we are predicting only on an instance
inputdata_reshaped=inputdata_as_numpy_array.reshape(1,-1)

#predicting result
prediction=classifier_lr.predict(inputdata_reshaped)


if prediction == 0:
    print("prediction : Iris setosa")
elif prediction == 1:
    print("prediction : Iris versicolor")
else:
    print("prediction : Iris virginica")
# Out:
# prediction : Iris versicolor

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
